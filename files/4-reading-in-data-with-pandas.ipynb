# %% [markdown]
# # Reading data from a file using pandas
# - What is Pandas?
# - How do I read files using Pandas?

# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/svenvanderburg/Desktop/python-bootcamp/notebooks'

# %%
# example
# pd.read_csv('/Users/svenvanderburg/Desktop/python-bootcamp/data/SN7577.tab

# %%
pd.read_csv('../data/

# %%
# /Users/svenvanderburg/Desktop/python-bootcamp/data/SN7577.tab
df = pd.read_csv('../data/SN7577.tab', sep='\t')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 1286

# %%
df.shape
# Out:
# (1286, 202)

# %%
df.columns
# Out:
# Index(['Q1', 'Q2', 'Q3', 'Q4', 'Q5ai', 'Q5aii', 'Q5aiii', 'Q5aiv', 'Q5av',
#        'Q5avi',
#        ...
#        'numhhd', 'numkid', 'numkid2', 'numkid31', 'numkid32', 'numkid33',
#        'numkid34', 'numkid35', 'numkid36', 'wts'],
#       dtype='object', length=202)

# %%
df.dtypes
# Out:
# Q1            int64
# Q2            int64
# Q3            int64
# Q4            int64
# Q5ai          int64
#              ...
# numkid33      int64
# numkid34      int64
# numkid35      int64
# numkid36      int64
# wts         float64
# Length: 202, dtype: object

# %%
df.head()
# Out:
#    Q1  Q2  Q3  Q4  Q5ai  Q5aii  Q5aiii  Q5aiv  Q5av  Q5avi  ...  numhhd  \
# 0   1  -1   1   8     0      0       0      1     0      0  ...       3
# 1   3  -1   1   4     0      0       0      0     0      0  ...       3
# 2  10   3   2   6     0      0       0      0     0      0  ...       2
# 3   9  -1  10  10     0      0       0      0     0      0  ...       1
# 4  10   2   6   1     0      0       0      1     0      0  ...       1
#
#    numkid  numkid2  numkid31  numkid32  numkid33  numkid34  numkid35  \
# 0      11        2         0         0         0         0         1
# 1      11        2         0         0         0         0         1
# 2      11        2         0         0         0         0         1
# 3      -1        2         0         0         0         0         1
# 4      -1        2         0         0         0         0         1
#
#    numkid36      wts
# 0         0  1.11439
# 1         0  2.56604
# 2         0  2.04468
# 3         0  1.07592
# 4         0  1.25068
#
# [5 rows x 202 columns]

# %% [markdown]
# ### Exercise: Reading in data using pandas
#
# #### Pandas sep
# 1. What happens if you forget to specify `sep='\t'` when reading a tab delimited dataset?
#
# #### Exercise: head and tail
# 1. As well as the `head()` method there is a `tail()` method. What do you think it does? Try it.
# 2. Both methods accept a single numeric parameter. What do you think it does? Try it.

# %%
df = pd.read_csv('../data/SN7577.tab')

# %%
df
# Out:
#      Q1\tQ2\tQ3\tQ4\tQ5ai\tQ5aii\tQ5aiii\tQ5aiv\tQ5av\tQ5avi\tQ5avii\tQ5aviii\tQ5aix\tQ5ax\tQ5axi\tQ5axii\tQ5axiii\tQ5axiv\tQ5axv\tQ5bi\tQ5bii\tQ5biii\tQ5biv\tQ5bv\tQ5bvi\tQ5bvii\tQ5bviii\tQ5bix\tQ5bx\tQ5bxi\tQ5bxii\tQ5bxiii\tQ5bxiv\tQ5bxv\tQ6\tQ7a\tQ7b\tQ8\tQ9\tQ10a\tQ10b\tQ10c\tQ10d\tQ11a\tQ11
# 0   1  -1   1   8     0      0       0      1     0      0  ...       3
# 1   3  -1   1   4     0      0       0      0     0      0  ...       3
# 2  10   3   2   6     0      0       0      0     0      0  ...       2
# 3   9  -1  10  10     0      0       0      0     0      0  ...       1
# 4  10   2   6   1     0      0       0      1     0      0  ...       1
#
#    numkid  numkid2  numkid31  numkid32  numkid33  numkid34  numkid35  \
# 0      11        2         0         0         0         0         1
# 1      11        2         0         0         0         0         1
# 2      11        2         0         0         0         0         1
# 3      -1        2         0         0         0         0         1
# 4      -1        2         0         0         0         0         1
#
#    numkid36      wts
# 0         0  1.11439
# 1         0  2.56604
# 2         0  2.04468
# 3         0  1.07592
# 4         0  1.25068
#
# [5 rows x 202 columns]

# %%
df.tail()
# Out:
#       Q1  Q2  Q3  Q4  Q5ai  Q5aii  Q5aiii  Q5aiv  Q5av  Q5avi  ...  numhhd  \
# 1281   2  -1   3   6     0      0       0      0     0      0  ...       2
# 1282  10  10   2  10     0      0       0      0     0      0  ...       1
# 1283   9  -1   8   9     0      0       0      0     0      0  ...       4
# 1284  11  11   1   2     0      0       0      1     1      0  ...       2
# 1285  10   6   6   6     0      0       0      0     0      0  ...       2
#
#       numkid  numkid2  numkid31  numkid32  numkid33  numkid34  numkid35  \
# 1281      -1        2         0         0         0         0         1
# 1282      -1        2         0         0         0         0         1
# 1283       2        1         1         0         0         0         0
# 1284      -1        2         0         0         0         0         1
# 1285      -1        2         0         0         0         0         1
#
#       numkid36      wts
# 1281         0  0.85231
# 1282         0  2.30831
# 1283         0  2.84823
# 1284         0  3.45887
# 1285         0  1.94413
#
# [5 rows x 202 columns]

# %%
df.tail(2)
# Out:
#       Q1  Q2  Q3  Q4  Q5ai  Q5aii  Q5aiii  Q5aiv  Q5av  Q5avi  ...  numhhd  \
# 1284  11  11   1   2     0      0       0      1     1      0  ...       2
# 1285  10   6   6   6     0      0       0      0     0      0  ...       2
#
#       numkid  numkid2  numkid31  numkid32  numkid33  numkid34  numkid35  \
# 1284      -1        2         0         0         0         0         1
# 1285      -1        2         0         0         0         0         1
#
#       numkid36      wts
# 1284         0  3.45887
# 1285         0  1.94413
#
# [2 rows x 202 columns]

# %%
df.tail(4)
# Out:
#       Q1  Q2  Q3  Q4  Q5ai  Q5aii  Q5aiii  Q5aiv  Q5av  Q5avi  ...  numhhd  \
# 1282  10  10   2  10     0      0       0      0     0      0  ...       1
# 1283   9  -1   8   9     0      0       0      0     0      0  ...       4
# 1284  11  11   1   2     0      0       0      1     1      0  ...       2
# 1285  10   6   6   6     0      0       0      0     0      0  ...       2
#
#       numkid  numkid2  numkid31  numkid32  numkid33  numkid34  numkid35  \
# 1282      -1        2         0         0         0         0         1
# 1283       2        1         1         0         0         0         0
# 1284      -1        2         0         0         0         0         1
# 1285      -1        2         0         0         0         0         1
#
#       numkid36      wts
# 1282         0  2.30831
# 1283         0  2.84823
# 1284         0  3.45887
# 1285         0  1.94413
#
# [4 rows x 202 columns]
